# %% [markdown]
# ## importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## load the data

# %%
data = pd.read_csv("datasets/Salary_Data.csv")

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
X = data.iloc[:,:-1].values
y = data.iloc[:,-1].values

# %% [markdown]
# ## split the data

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=1)
X_train.shape,X_test.shape
# Out:
# ((24, 1), (6, 1))

# %% [markdown]
# ## train and predict using simple linear regression model

# %%
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
reg.coef_[0],reg.intercept_
# Out:
# (9332.944737992719, 25609.897998354834)

# %%
reg.predict([[10]])
# Out:
# array([118939.34537828])

# %% [markdown]
# ## visualize real  and pred salaries data

# %%
plt.scatter(X_train,y_train,color='red')
plt.plot(X_train,reg.predict(X_train))
plt.title("salary vs experience(train)")
plt.xlabel("experience")
plt.ylabel("salary")
plt.show()

# %%
plt.scatter(X_test,y_test,color='red')
plt.plot(X_train,reg.predict(X_train))
plt.title("salary vs experience(test)")
plt.xlabel("experience")
plt.ylabel("salary")
plt.show()
